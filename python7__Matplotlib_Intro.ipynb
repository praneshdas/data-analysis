# %% [markdown]
# <a href="https://colab.research.google.com/github/praneshdas/data-analysis/blob/main/python7__Matplotlib_Intro.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib

print(matplotlib.__version__)
# Out:
# 3.7.1

# %%
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# <br>
#
# <h2> 1. Drawing a simple plot </h2>
#
# <br>

# %%
# A simple plot: A sinusoid

x = np.linspace(0, 10, 200)
y = np.sin(x)

plt.plot(x, y)
plt.show()

# %% [markdown]
# <br>
#
# <h2> 2.  Plotting curves and adding a legend </h2>
#
# <br>

# %%
# Different ways in which a plot can be customized:

x = np.linspace(0, 10, 200)
sine_x = np.sin(x)

# Set a plot size and dpi
plt.figure(figsize=(11,6), dpi=200)

# Plot f(x) with a 'green' colour, set the line width, and label the line as 'sine'
[line_handle] = plt.plot(x, sine_x, c='m', linewidth=4, label='sine')

# Plot a second function of x
cosine_x = np.cos(x)

# #RRGGBB
[line_handle2] = plt.plot(x, cosine_x, c='r', linewidth=2, label='cos')

# Create a legend for the plot
plt.legend(handles=[line_handle, line_handle2], fontsize=30, loc='lower right', shadow=True)

# Customize the axis ticks, axis labels, and the plot title
plt.xticks(fontsize=20)
plt.yticks([-1, -0.5, 0, 0.5, 1], [-1, -0.5, 0, 0.5, 1], fontsize=20)
plt.xlabel('x axis', fontsize=30)
plt.ylabel('y axis', fontsize=30)
plt.title('Lets have a plot', fontsize=30)
plt.show()

# %%
line_handle

# %% [markdown]
# <br>
#
# <h2> 3. Drawing a customized scatter plot </h2>
#
# <br>

# %%
# A customized scatter plot

# Generate random data from a 2-dimensional Gaussian distribution
x1 = np.random.normal(loc=[0,0], scale=1, size=(50,2))
print('x1 :\n', x1, '\n')

plt.figure(figsize=(9,6), dpi=150)

# Create a scatter plot marked with 'o' points
g1 = plt.scatter(
    x1[:,0], x1[:,1], marker='o', s=80, c='w', edgecolor='g',
    label='Gaussian #1'
)

# Generate more random data from 2-dimensional Gaussian distributions
x2 = np.random.normal(loc=[10,-1], scale=0.5, size=(50,2))
x3 = np.random.normal(loc=[8,5], scale=1.5, size=(50,2))


# Plot x2 and x3
g2 = plt.scatter(x2[:,0], x2[:,1], marker='x', s=80, c='r',  label='Gaussian #2'
)
g3 = plt.scatter(
    x3[:,0], x3[:,1], marker='d', s=80, c='w', edgecolor='b',
    label='Gaussian #3'
)

# Position the legend
plt.legend(
        handles=[g1, g2, g3], fontsize=30, shadow=True,
    bbox_to_anchor=(1.03, 1), borderaxespad=0
)

plt.xticks(fontsize=20)
plt.yticks(fontsize=20)
plt.xlabel('Feature 1', fontsize=30)
plt.ylabel('Feature 2', fontsize=30)
plt.title('Mixture of 3 Gaussians', fontsize=30)
plt.show()
# Out:
# x1 :
#  [[-5.73176994e-02  1.12627871e+00]
#  [ 5.33271095e-01 -2.12620445e-01]
#  [ 7.01564074e-02  3.39050657e-01]
#  [ 1.30407809e-01  1.11582433e+00]
#  [ 7.89679537e-01 -3.96014990e-01]
#  [-1.55160402e-01 -8.33747148e-01]
#  [ 1.52119983e+00  1.17294216e-01]
#  [ 6.12506627e-01  2.86946518e-01]
#  [-4.84943522e-01  3.35168253e-01]
#  [-1.86900941e+00  2.61004715e-01]
#  [-5.75670131e-02 -7.20746251e-01]
#  [ 5.29612289e-01  4.36085545e-01]
#  [ 7.96838772e-01  6.05279612e-02]
#  [ 2.18218879e+00  1.64484155e+00]
#  [-1.30443775e+00 -2.33354277e-01]
#  [ 1.74578222e-01 -2.93301716e-01]
#  [-1.44954237e+00 -2.45372783e-01]
#  [-1.59523558e+00 -3.50034434e-01]
#  [ 4.97045880e-01  9.88244477e-01]
#  [ 1.93856769e+00  5.32340979e-01]
#  [ 9.34139387e-01  3.80201852e-02]
#  [-6.51881914e-01 -9.18888813e-01]
#  [ 6.85802170e-02  1.29310245e+00]
#  [ 2.76699612e-01 -1.57534151e+00]
#  [ 4.91527888e-01 -8.19264426e-01]
#  [-5.57457725e-01  3.43600446e-01]
# ...

# %%
# To check which image file types are supported, to save the plot to
plt.gcf().canvas.get_supported_filetypes()

#plt.savefig('scatter_demo.png', dpi=300, bbox_inches='tight', pad_inches=0.05)
# Out:
# {'ps': 'Postscript',
#  'eps': 'Encapsulated Postscript',
#  'pdf': 'Portable Document Format',
#  'pgf': 'PGF code for LaTeX',
#  'png': 'Portable Network Graphics',
#  'raw': 'Raw RGBA bitmap',
#  'rgba': 'Raw RGBA bitmap',
#  'svg': 'Scalable Vector Graphics',
#  'svgz': 'Scalable Vector Graphics',
#  'jpg': 'Joint Photographic Experts Group',
#  'jpeg': 'Joint Photographic Experts Group',
#  'tif': 'Tagged Image File Format',
#  'tiff': 'Tagged Image File Format'}

# %% [markdown]
# <br>
#
# <h2> 4. Visualization data with 3D Plot </h2>
#
# <br>

# %%
# Plotting in 3D

import numpy as np
import matplotlib.pyplot as plt

fig = plt.figure(dpi=120)
ax = plt.axes(projection='3d')

n = 100
xs = np.random.rand(n)
ys = np.random.rand(n)
zs = np.random.rand(n)



# Plot points with z < 0.5 marked differently than z >= 0.5
mask = zs < 0.5
c = ['r', 'b']
m = ['o', '^']
ax.scatter(xs[mask==0], ys[mask==0], zs[mask==0], c=c[0], marker=m[0])
ax.scatter(xs[mask==1], ys[mask==1], zs[mask==1], c=c[1], marker=m[1])

#Labelling the axis
ax.set_xlabel('X Label')
ax.set_ylabel('Y Label')
ax.set_zlabel('Z Label')


plt.title("3D Plotting")

#Viewing the 3-D plot from different angles
ax.view_init(45, 45)

plt.show()

# %% [markdown]
# Matpltlob documentation gallery -
# https://matplotlib.org/stable/gallery/index
